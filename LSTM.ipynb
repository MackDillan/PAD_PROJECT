# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasRegressor
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go

# %%
df_2020 = pd.read_csv('grouped/2020/grouped_by_subcat_2020.csv', encoding='UTF-8')
df_2021 = pd.read_csv('grouped/2021/grouped_by_subcat_2021.csv', encoding='UTF-8')
df = pd.concat([df_2021, df_2020], axis=0)

#df = pd.concat([df, df_2020], axis=0)
df = df[df['CATEGORY'] == 'Сковорода']
df
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.groupby(['DATE','CATEGORY']).agg({'QUANTITY': 'sum'}).reset_index()
df = df[['DATE', 'QUANTITY']]
train_data = df
train_data
# Out:
#           DATE  QUANTITY
# 0   2020-01-01      21.0
# 1   2020-01-02     424.0
# 2   2020-01-03     292.0
# 3   2020-01-04     352.0
# 4   2020-01-05     592.0
# ..         ...       ...
# 726 2021-12-27     429.0
# 727 2021-12-28     518.0
# 728 2021-12-29     625.0
# 729 2021-12-30     812.0
# 730 2021-12-31     860.0
#
# [731 rows x 2 columns]

# %%
data_real = pd.read_csv('grouped/2023/grouped_by_subcat_2023.csv', encoding='UTF-8')
data_real = data_real[data_real['CATEGORY'] == 'Сковорода']
data_real['DATE'] = pd.to_datetime(data_real['DATE']) 
data_real = data_real.groupby(['DATE','CATEGORY']).agg({'QUANTITY': 'sum'}).reset_index()
data_real = data_real[['DATE', 'QUANTITY']]
data_real
# Out:
#           DATE  QUANTITY
# 0   2023-01-01      11.0
# 1   2023-01-02     313.0
# 2   2023-01-03     229.0
# 3   2023-01-04     224.0
# 4   2023-01-05     246.0
# ..         ...       ...
# 360 2023-12-27     327.0
# 361 2023-12-28     436.0
# 362 2023-12-29     559.0
# 363 2023-12-30     885.0
# 364 2023-12-31     608.0
#
# [365 rows x 2 columns]

# %%
df_2022 = pd.read_csv('grouped/2022/grouped_by_subcat_2022.csv', encoding='UTF-8')
df_2022 = df_2022[df_2022['CATEGORY'] == 'Сковорода']
df_2022 = df_2022.groupby(['DATE','CATEGORY']).agg({'QUANTITY': 'sum'}).reset_index()
df_2022 = df_2022[['DATE', 'QUANTITY']]
df_2022
test_data = df_2022
test_data.reset_index(drop=True, inplace=True)
test_data
# Out:
#            DATE  QUANTITY
# 0    2022-01-01      18.0
# 1    2022-01-02     331.0
# 2    2022-01-03     167.0
# 3    2022-01-04     220.0
# 4    2022-01-05     264.0
# ..          ...       ...
# 360  2022-12-27     474.0
# 361  2022-12-28     547.0
# 362  2022-12-29     719.0
# 363  2022-12-30    1022.0
# 364  2022-12-31     871.0
#
# [365 rows x 2 columns]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train_data = scaler.fit_transform(train_data['QUANTITY'].values.reshape(-1, 1))
scaled_test_data = scaler.transform(test_data['QUANTITY'].values.reshape(-1, 1))

def create_window_data(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 60  

X_train, y_train = create_window_data(scaled_train_data, window_size)
X_test, y_test = create_window_data(scaled_test_data, window_size)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

model = Sequential()
model.add(LSTM(units=175, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.25))
model.add(LSTM(units=150, return_sequences=True))
model.add(Dropout(0.25))
model.add(LSTM(units=120))
model.add(Dropout(0.25))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model.fit(X_train, y_train, epochs=75, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])

predicted_sales = model.predict(X_test)
predicted_sales = scaler.inverse_transform(predicted_sales)
predicted_sales
# Out:
# Epoch 1/75
# C:\Users\Viktar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 0.0308 - val_loss: 0.0122
# Epoch 2/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0149 - val_loss: 0.0121
# Epoch 3/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0142 - val_loss: 0.0115
# Epoch 4/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0124 - val_loss: 0.0131
# Epoch 5/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0121 - val_loss: 0.0111
# Epoch 6/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0135 - val_loss: 0.0120
# Epoch 7/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0156 - val_loss: 0.0107
# Epoch 8/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0130 - val_loss: 0.0110
# Epoch 9/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 0.0142 - val_loss: 0.0105
# Epoch 10/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0114 - val_loss: 0.0108
# Epoch 11/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 0.0111 - val_loss: 0.0109
# Epoch 12/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0149 - val_loss: 0.0125
# Epoch 13/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0134 - val_loss: 0.0106
# Epoch 14/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0118 - val_loss: 0.0103
# Epoch 15/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0141 - val_loss: 0.0105
# Epoch 16/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0128 - val_loss: 0.0107
# Epoch 17/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0138 - val_loss: 0.0103
# Epoch 18/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0122 - val_loss: 0.0104
# Epoch 19/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0132 - val_loss: 0.0105
# Epoch 20/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0164 - val_loss: 0.0103
# Epoch 21/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.0130 - val_loss: 0.0102
# Epoch 22/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0116 - val_loss: 0.0110
# Epoch 23/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0140 - val_loss: 0.0102
# Epoch 24/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.0131 - val_loss: 0.0105
# Epoch 25/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0130 - val_loss: 0.0103
# Epoch 26/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0121 - val_loss: 0.0102
# Epoch 27/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0116 - val_loss: 0.0102
# Epoch 28/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 114ms/step - loss: 0.0147 - val_loss: 0.0101
# Epoch 29/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0112 - val_loss: 0.0104
# Epoch 30/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 0.0116 - val_loss: 0.0100
# Epoch 31/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.0148 - val_loss: 0.0100
# Epoch 32/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 33/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0104 - val_loss: 0.0112
# Epoch 34/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0111 - val_loss: 0.0097
# Epoch 35/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0115 - val_loss: 0.0095
# Epoch 36/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0124 - val_loss: 0.0096
# Epoch 37/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0132 - val_loss: 0.0091
# Epoch 38/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0109 - val_loss: 0.0089
# Epoch 39/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0130 - val_loss: 0.0089
# Epoch 40/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0103 - val_loss: 0.0079
# Epoch 41/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.0100 - val_loss: 0.0091
# Epoch 42/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0113 - val_loss: 0.0078
# Epoch 43/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 0.0082 - val_loss: 0.0076
# Epoch 44/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0109 - val_loss: 0.0079
# Epoch 45/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0116 - val_loss: 0.0078
# Epoch 46/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0090 - val_loss: 0.0072
# Epoch 47/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0099 - val_loss: 0.0078
# Epoch 48/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0106 - val_loss: 0.0072
# Epoch 49/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 50/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0087 - val_loss: 0.0070
# Epoch 51/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 52/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0091 - val_loss: 0.0068
# Epoch 53/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0070 - val_loss: 0.0066
# Epoch 54/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 55/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0071 - val_loss: 0.0064
# Epoch 56/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0083 - val_loss: 0.0067
# Epoch 57/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0077 - val_loss: 0.0062
# Epoch 58/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0073 - val_loss: 0.0054
# Epoch 59/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0080 - val_loss: 0.0053
# Epoch 60/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 61/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 62/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0066 - val_loss: 0.0050
# Epoch 63/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 64/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 65/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 66/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0084 - val_loss: 0.0054
# Epoch 67/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 68/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 69/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0056 - val_loss: 0.0046
# Epoch 70/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 0.0065 - val_loss: 0.0041
# Epoch 71/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 72/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 73/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0055 - val_loss: 0.0040
# Epoch 74/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0071 - val_loss: 0.0039
# Epoch 75/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0048 - val_loss: 0.0038
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# array([[240.72847 ],
#        [285.30084 ],
#        [393.19183 ],
#        [550.97955 ],
#        [556.6295  ],
#        [400.5401  ],
#        [441.10757 ],
#        [514.33746 ],
#        [463.94675 ],
#        [410.90073 ],
#        [451.93765 ],
#        [510.14322 ],
#        [382.84122 ],
#        [217.92595 ],
#        [215.54286 ],
#        [217.42526 ],
#        [218.99086 ],
#        [276.53677 ],
#        [342.1205  ],
#        [230.30182 ],
#        [125.67464 ],
#        [110.62823 ],
#        [110.440216],
#        [119.06687 ],
#        [172.17279 ],
#        [227.69919 ],
#        [157.96933 ],
#        [ 93.732635],
#        [ 92.65227 ],
#        [ 84.78722 ],
#        [111.71923 ],
#        [205.74489 ],
#        [256.2859  ],
#        [151.01405 ],
#        [ 97.97308 ],
#        [109.14254 ],
#        [117.46058 ],
#        [147.68604 ],
#        [254.33893 ],
#        [306.9414  ],
#        [178.99817 ],
#        [125.2911  ],
#        [139.83238 ],
#        [136.70963 ],
#        [154.5175  ],
#        [253.70651 ],
#        [298.20255 ],
#        [152.59619 ],
#        [102.74654 ],
#        [130.09631 ],
#        [127.24255 ],
#        [154.88356 ],
#        [274.05698 ],
#        [303.75964 ],
#        [133.04704 ],
#        [ 83.96585 ],
#        [106.55226 ],
#        [129.72026 ],
#        [163.2958  ],
#        [226.18488 ],
#        [222.86415 ],
#        [134.54018 ],
#        [ 82.991035],
#        [ 90.14352 ],
#        [104.43212 ],
#        [129.88634 ],
#        [174.98537 ],
#        [214.39305 ],
#        [166.27919 ],
#        [125.07922 ],
#        [128.90485 ],
#        [186.60869 ],
#        [238.90585 ],
#        [268.87585 ],
#        [287.86343 ],
#        [269.5954  ],
#        [201.75327 ],
#        [175.14099 ],
#        [168.44887 ],
#        [179.67358 ],
#        [218.01257 ],
#        [266.03812 ],
#        [223.72441 ],
#        [169.32565 ],
#        [163.66986 ],
#        [168.62653 ],
#        [210.78455 ],
#        [298.66223 ],
#        [317.3092  ],
#        [223.65695 ],
#        [159.20145 ],
#        [173.26761 ],
#        [187.18031 ],
#        [221.99696 ],
#        [270.11035 ],
#        [292.81415 ],
#        [207.0817  ],
#        [136.52202 ],
#        [136.83147 ],
#        [154.06679 ],
#        [185.84872 ],
#        [269.28104 ],
#        [306.7211  ],
#        [243.39137 ],
#        [181.3447  ],
#        [182.38914 ],
#        [191.36842 ],
#        [216.08646 ],
#        [296.52917 ],
#        [317.621   ],
#        [218.96887 ],
#        [154.56929 ],
#        [169.1197  ],
#        [205.63127 ],
#        [247.31107 ],
#        [300.10046 ],
#        [312.2379  ],
#        [253.82864 ],
#        [184.4664  ],
#        [163.23595 ],
#        [172.77022 ],
#        [195.93677 ],
#        [219.42612 ],
#        [213.27711 ],
#        [175.41783 ],
#        [143.8446  ],
#        [142.07503 ],
#        [160.82059 ],
#        [197.25745 ],
#        [242.18224 ],
#        [264.01617 ],
#        [254.90942 ],
#        [220.71529 ],
#        [207.59091 ],
#        [203.82697 ],
#        [240.45898 ],
#        [304.3647  ],
#        [301.38547 ],
#        [220.34572 ],
#        [191.28174 ],
#        [209.88376 ],
#        [228.18623 ],
#        [272.62115 ],
#        [379.734   ],
#        [368.14334 ],
#        [252.52525 ],
#        [196.97594 ],
#        [208.91615 ],
#        [241.2484  ],
#        [299.07968 ],
#        [389.52484 ],
#        [385.5333  ],
#        [283.2439  ],
#        [209.61417 ],
#        [212.83989 ],
#        [234.27039 ],
#        [261.17426 ],
#        [310.25864 ],
#        [320.72952 ],
#        [258.3857  ],
#        [200.84483 ],
#        [195.5219  ],
#        [212.17778 ],
#        [272.4435  ],
#        [358.73264 ],
#        [375.78076 ],
#        [295.9622  ],
#        [231.85545 ],
#        [227.8638  ],
#        [233.24611 ],
#        [271.1765  ],
#        [348.1036  ],
#        [342.26904 ],
#        [251.82454 ],
#        [207.99805 ],
#        [218.90276 ],
#        [249.6877  ],
#        [312.28036 ],
#        [382.4168  ],
#        [375.1352  ],
#        [292.996   ],
#        [234.49646 ],
#        [228.21703 ],
#        [235.43445 ],
#        [262.99713 ],
#        [329.50873 ],
#        [355.70157 ],
#        [250.42368 ],
#        [190.65886 ],
#        [202.58708 ],
#        [213.20195 ],
#        [267.83655 ],
#        [405.62076 ],
#        [429.13422 ],
#        [297.4078  ],
#        [227.29692 ],
#        [224.9381  ],
#        [209.04478 ],
#        [254.78244 ],
#        [393.0201  ],
#        [392.88272 ],
#        [221.2657  ],
#        [181.15192 ],
#        [203.13676 ],
#        [216.60745 ],
#        [282.70602 ],
#        [420.75266 ],
#        [411.4953  ],
#        [241.51517 ],
#        [184.28114 ],
#        [202.31621 ],
#        [216.67221 ],
#        [264.95844 ],
#        [341.72458 ],
#        [336.2241  ],
#        [213.27719 ],
#        [157.9459  ],
#        [165.7945  ],
#        [169.22278 ],
#        [215.00894 ],
#        [301.07147 ],
#        [306.41785 ],
#        [205.421   ],
#        [162.22343 ],
#        [175.10272 ],
#        [202.27814 ],
#        [260.72937 ],
#        [415.4157  ],
#        [386.3913  ],
#        [265.50317 ],
#        [217.98051 ],
#        [190.98363 ],
#        [173.6559  ],
#        [227.54642 ],
#        [335.24677 ],
#        [273.9828  ],
#        [166.34518 ],
#        [180.26451 ],
#        [206.18738 ],
#        [178.31303 ],
#        [230.61693 ],
#        [438.73862 ],
#        [395.93265 ],
#        [156.89787 ],
#        [144.4221  ],
#        [202.70123 ],
#        [224.3629  ],
#        [286.02615 ],
#        [409.47064 ],
#        [399.11346 ],
#        [226.40987 ],
#        [181.94917 ],
#        [201.37741 ],
#        [195.26584 ],
#        [220.14438 ],
#        [399.93857 ],
#        [447.10632 ],
#        [259.04153 ],
#        [206.33006 ],
#        [219.79767 ],
#        [195.89806 ],
#        [246.11975 ],
#        [489.52133 ],
#        [476.6305  ],
#        [224.20895 ],
#        [200.0493  ],
#        [232.55559 ],
#        [230.90643 ],
#        [288.56113 ],
#        [529.47205 ],
#        [488.91824 ],
#        [248.1948  ],
#        [222.05235 ],
#        [246.13947 ],
#        [226.26831 ],
#        [280.39685 ],
#        [482.57025 ],
#        [463.3054  ],
#        [214.28877 ],
#        [203.5332  ],
#        [257.09814 ],
#        [232.88544 ],
#        [252.37323 ],
#        [476.38794 ],
#        [508.70392 ],
#        [209.80714 ],
#        [177.0022  ],
#        [221.4944  ],
#        [246.61377 ],
#        [331.4505  ],
#        [467.5803  ],
#        [453.95737 ],
#        [269.01727 ],
#        [218.0981  ],
#        [258.99094 ],
#        [284.0808  ],
#        [380.5059  ],
#        [543.05457 ],
#        [608.162   ],
#        [365.2055  ],
#        [308.22913 ],
#        [364.4752  ],
#        [450.84064 ],
#        [712.35675 ],
#        [988.0535  ]], dtype=float32)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

data_2023 = test_data

scaled_data_2023 = scaler.fit_transform(data_2023['QUANTITY'].values.reshape(-1, 1))

def create_window_data(data, window_size):
    X = []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i, 0])
    return np.array(X)

window_size = 30  
X_2023 = create_window_data(scaled_data_2023, window_size)
X_2023 = np.reshape(X_2023, (X_2023.shape[0], X_2023.shape[1], 1))

predictions = []
input_seq = X_2023[-1] 

for _ in range(60): 
    pred = model.predict(input_seq.reshape(1, window_size, 1))
    predictions.append(pred[0][0])
    input_seq = np.append(input_seq[1:], pred).reshape(window_size, 1)

predictions = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))

prediction_dates = pd.date_range(start='2024-01-01', periods=60)
predicted_sales_df = pd.DataFrame(predictions, columns=['QUANTITY'])
predicted_sales_df['DATE'] = prediction_dates


print("Предсказания на первые два месяца 2024 года:")
print(predicted_sales_df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Предсказания на первые два месяца 2024 года:
#       QUANTITY       DATE
# 0   550.654236 2024-01-01
# 1   292.735229 2024-01-02
# 2   292.491730 2024-01-03
# 3   265.642426 2024-01-04
# 4   286.336700 2024-01-05
# 5   354.550323 2024-01-06
# 6   365.918213 2024-01-07
# 7   274.675934 2024-01-08
# 8   220.174576 2024-01-09
# 9   206.468887 2024-01-10
# 10  201.984680 2024-01-11
# 11  216.497681 2024-01-12
# 12  255.626816 2024-01-13
# 13  287.475494 2024-01-14
# 14  256.529358 2024-01-15
# 15  200.028107 2024-01-16
# 16  178.226181 2024-01-17
# 17  173.925812 2024-01-18
# 18  185.767502 2024-01-19
# 19  229.291321 2024-01-20
# 20  280.889984 2024-01-21
# 21  255.852203 2024-01-22
# 22  185.145218 2024-01-23
# 23  166.405045 2024-01-24
# 24  163.013718 2024-01-25
# 25  173.234695 2024-01-26
# 26  225.850510 2024-01-27
# 27  296.515747 2024-01-28
# 28  262.674225 2024-01-29
# 29  175.150528 2024-01-30
# 30  163.809967 2024-01-31
# 31  161.968506 2024-02-01
# 32  171.735840 2024-02-02
# 33  227.756165 2024-02-03
# 34  304.667999 2024-02-04
# 35  268.271820 2024-02-05
# 36  174.718124 2024-02-06
# 37  165.444397 2024-02-07
# 38  164.357162 2024-02-08
# 39  174.156723 2024-02-09
# 40  232.649841 2024-02-10
# 41  314.092072 2024-02-11
# 42  274.705872 2024-02-12
# 43  176.809021 2024-02-13
# 44  169.303131 2024-02-14
# 45  167.996872 2024-02-15
# 46  178.079330 2024-02-16
# 47  238.670059 2024-02-17
# 48  322.373993 2024-02-18
# 49  279.410492 2024-02-19
# 50  179.563400 2024-02-20
# 51  172.991837 2024-02-21
# 52  171.223190 2024-02-22
# 53  181.729446 2024-02-23
# 54  243.985107 2024-02-24
# 55  328.296417 2024-02-25
# 56  281.842377 2024-02-26
# 57  181.658463 2024-02-27
# 58  175.593552 2024-02-28
# 59  173.408600 2024-02-29

# %%
predicted_sales_df
# Out:
#       QUANTITY       DATE
# 0   550.654236 2024-01-01
# 1   292.735229 2024-01-02
# 2   292.491730 2024-01-03
# 3   265.642426 2024-01-04
# 4   286.336700 2024-01-05
# 5   354.550323 2024-01-06
# 6   365.918213 2024-01-07
# 7   274.675934 2024-01-08
# 8   220.174576 2024-01-09
# 9   206.468887 2024-01-10
# 10  201.984680 2024-01-11
# 11  216.497681 2024-01-12
# 12  255.626816 2024-01-13
# 13  287.475494 2024-01-14
# 14  256.529358 2024-01-15
# 15  200.028107 2024-01-16
# 16  178.226181 2024-01-17
# 17  173.925812 2024-01-18
# 18  185.767502 2024-01-19
# 19  229.291321 2024-01-20
# 20  280.889984 2024-01-21
# 21  255.852203 2024-01-22
# 22  185.145218 2024-01-23
# 23  166.405045 2024-01-24
# 24  163.013718 2024-01-25
# 25  173.234695 2024-01-26
# 26  225.850510 2024-01-27
# 27  296.515747 2024-01-28
# 28  262.674225 2024-01-29
# 29  175.150528 2024-01-30
# 30  163.809967 2024-01-31
# 31  161.968506 2024-02-01
# 32  171.735840 2024-02-02
# 33  227.756165 2024-02-03
# 34  304.667999 2024-02-04
# 35  268.271820 2024-02-05
# 36  174.718124 2024-02-06
# 37  165.444397 2024-02-07
# 38  164.357162 2024-02-08
# 39  174.156723 2024-02-09
# 40  232.649841 2024-02-10
# 41  314.092072 2024-02-11
# 42  274.705872 2024-02-12
# 43  176.809021 2024-02-13
# 44  169.303131 2024-02-14
# 45  167.996872 2024-02-15
# 46  178.079330 2024-02-16
# 47  238.670059 2024-02-17
# 48  322.373993 2024-02-18
# 49  279.410492 2024-02-19
# 50  179.563400 2024-02-20
# 51  172.991837 2024-02-21
# 52  171.223190 2024-02-22
# 53  181.729446 2024-02-23
# 54  243.985107 2024-02-24
# 55  328.296417 2024-02-25
# 56  281.842377 2024-02-26
# 57  181.658463 2024-02-27
# 58  175.593552 2024-02-28
# 59  173.408600 2024-02-29

# %%
predicted_dates = test_data['DATE'].iloc[window_size:]
predicted_df = pd.DataFrame({'DATE': predicted_dates, 'QUANTITY': predicted_sales.flatten()})
predicted_df.reset_index(drop=True, inplace=True)
predicted_df
# Out:
#            DATE    QUANTITY
# 0    2022-03-02  240.728470
# 1    2022-03-03  285.300842
# 2    2022-03-04  393.191833
# 3    2022-03-05  550.979553
# 4    2022-03-06  556.629517
# ..          ...         ...
# 300  2022-12-27  308.229126
# 301  2022-12-28  364.475189
# 302  2022-12-29  450.840637
# 303  2022-12-30  712.356750
# 304  2022-12-31  988.053528
#
# [305 rows x 2 columns]

# %%
# Создание Dash приложения

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Прогнозирование продаж"),
    dcc.Graph(id='sales-forecast-graph')
])

@app.callback(
    Output('sales-forecast-graph', 'figure'),
    [Input('sales-forecast-graph', 'id')]
)
def update_graph(_):
    fig = go.Figure()

    fig.add_trace(go.Scatter(x=test_data['DATE'], y=test_data['QUANTITY'], mode='lines', name='Обучение'))

    fig.add_trace(go.Scatter(x=data_real['DATE'], y=data_real['QUANTITY'], mode='lines', name='Реальность'))
    fig.add_trace(go.Scatter(x=predicted_df['DATE'], y=predicted_df['QUANTITY'], mode='lines', name='Прогноз'))

    fig.update_layout(
        title="Прогнозирование продаж",
        xaxis_title="Дата",
        yaxis_title="Количество продаж",
        legend_title="Информация"
    )
    return fig

app.run_server(debug=True, port=5099)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5099/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(test_data['QUANTITY'][window_size:], predicted_sales)
print("Mean Absolute Error on Test Data:", mae)
# Out:
# Mean Absolute Error on Test Data: 38.8466798696945
